# %%
from data_query import query_functions_local

# %%
query_functions_local.query_data('/mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0004/')
# Out:
# /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0004/HTF0004_CV384W_201__2023-11-20T22_15_42-Measurement 4/Images/r03c03f01p01-ch1sk1fk1fl1.tiff
#                                                 file_path
# 0       /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...  \
# 1       /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
# 2       /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
# 3       /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
# 4       /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
# ...                                                   ...
# 352795  /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
# 352796  /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
# 352797  /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
# 352798  /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
# 352799  /mnt/3b0129e9-916e-4029-a23f-615712223e70/HTF0...
#
#                               filename plate    well site channel plane
# ...

# %%
from data_query import query_functions_local

# %%
query_functions_local.query_data(exp_folder='/mnt/synology01/HTF0004/')
# Out:
# /mnt/synology01/HTF0004/HTF0004_CV384W_201__2023-11-20T22_15_42-Measurement 4/Images/r03c03f01p01-ch1sk1fk1fl1.tiff
#                                                 file_path  \
# 0       /mnt/synology01/HTF0004/HTF0004_CV384W_201__20...
# 1       /mnt/synology01/HTF0004/HTF0004_CV384W_201__20...
# 2       /mnt/synology01/HTF0004/HTF0004_CV384W_201__20...
# 3       /mnt/synology01/HTF0004/HTF0004_CV384W_201__20...
# 4       /mnt/synology01/HTF0004/HTF0004_CV384W_201__20...
# ...                                                   ...
# 352795  /mnt/synology01/HTF0004/HTF0004_CV384W_206__20...
# 352796  /mnt/synology01/HTF0004/HTF0004_CV384W_206__20...
# 352797  /mnt/synology01/HTF0004/HTF0004_CV384W_206__20...
# 352798  /mnt/synology01/HTF0004/HTF0004_CV384W_206__20...
# 352799  /mnt/synology01/HTF0004/HTF0004_CV384W_206__20...
#
#                               filename plate    well site channel plane
# 0       r03c03f01p01-ch1sk1fk1fl1.tiff   201  r03c03  f01     ch1   p01
# ...

# %%
query_functions_local.query_data_updated(exp_folder='/mnt/synology01/HTF0004/',plate_type='_CV384W_',pattern='Images/<Well(6)><Site(3)><Plane(3)>-<Channel(3)>.<ext>',exts=('tiff',),delimiters=('-','.'))
# Out:
# 6 plate founds!
# finding files matching pattern: /mnt/synology01/HTF0004/HTF0004_CV384W_201__2023-11-20T22_15_42-Measurement 4/Images/*-*.tiff
# finding files matching pattern: /mnt/synology01/HTF0004/HTF0004_CV384W_202__2023-11-21T22_39_40-Measurement 4/Images/*-*.tiff
# finding files matching pattern: /mnt/synology01/HTF0004/HTF0004_CV384W_203__2023-11-22T21_29_11-Measurement 4/Images/*-*.tiff
# finding files matching pattern: /mnt/synology01/HTF0004/HTF0004_CV384W_204__2023-11-21T03_47_42-Measurement 4/Images/*-*.tiff
# finding files matching pattern: /mnt/synology01/HTF0004/HTF0004_CV384W_205__2023-11-22T04_10_44-Measurement 4/Images/*-*.tiff
# finding files matching pattern: /mnt/synology01/HTF0004/HTF0004_CV384W_206__2023-11-23T03_00_56-Measurement 4/Images/*-*.tiff
#                                                     plate    well site  \
# 0       HTF0004_CV384W_201__2023-11-20T22_15_42-Measur...  r03c03  f01
# ...

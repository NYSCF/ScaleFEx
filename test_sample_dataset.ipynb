# %%
import scalefex_main

pipeline=scalefex_main.Process_HighContentImaging_screen()
pipeline.run()
# Out:
# Checking parameters in parameters.yaml...
# - Parameter subset_index (all) must be a positive integer.
# retrieving files from  sample_data/
# 1 plate(s) found!
# finding files matching pattern: sample_data/ScaleFEx_Dataset01_Plate1/*f*p*-*.tiff
#     plate    well site channel plane                        filename  \
# 0  Plate1  r03c03   01     ch1    01  r03c03f01p01-ch1sk1fk1fl1.tiff
# 1  Plate1  r03c03   01     ch2    01  r03c03f01p01-ch2sk1fk1fl1.tiff
# 2  Plate1  r03c03   01     ch3    01  r03c03f01p01-ch3sk1fk1fl1.tiff
# 3  Plate1  r03c03   01     ch4    01  r03c03f01p01-ch4sk1fk1fl1.tiff
# 4  Plate1  r03c03   01     ch5    01  r03c03f01p01-ch5sk1fk1fl1.tiff
#
#                 plate_folder  \
# 0  ScaleFEx_Dataset01_Plate1
# 1  ScaleFEx_Dataset01_Plate1
# 2  ScaleFEx_Dataset01_Plate1
# 3  ScaleFEx_Dataset01_Plate1
# 4  ScaleFEx_Dataset01_Plate1
#
#                                            file_path
# 0  sample_data/ScaleFEx_Dataset01_Plate1/r03c03f0...
# ...

# %%
from data_query import query_functions_local

# %%
folder='/mnt/10b1e8d4-f3a8-46e5-9a1a-c197b4f39011/HTF0002/'
pattern='Images/<Well>f<Site>p<Plane(2)>-<Channel(3)>.<ext>'
plate_identifiers=('_C384W_','_')

files=query_functions_local.query_data(folder,pattern,plate_identifiers=plate_identifiers,exts=('tiff',))
# Out:
# retrieving files from  /mnt/10b1e8d4-f3a8-46e5-9a1a-c197b4f39011/HTF0002/
# 6 plate(s) found!
# finding files matching pattern: /mnt/10b1e8d4-f3a8-46e5-9a1a-c197b4f39011/HTF0002/HTF0002_C384W_201__1023-07-07T22_09_04-Measurement 3/Images/*f*p*-*.tiff
# finding files matching pattern: /mnt/10b1e8d4-f3a8-46e5-9a1a-c197b4f39011/HTF0002/HTF0002_C384W_202__1023-07-08T22_18_21-Measurement 3/Images/*f*p*-*.tiff
# finding files matching pattern: /mnt/10b1e8d4-f3a8-46e5-9a1a-c197b4f39011/HTF0002/HTF0002_C384W_203__2023-07-09T21_58_34-Measurement 3/Images/*f*p*-*.tiff
# finding files matching pattern: /mnt/10b1e8d4-f3a8-46e5-9a1a-c197b4f39011/HTF0002/HTF0002_C384W_204__2023-07-08T03_37_24-Measurement 3/Images/*f*p*-*.tiff
# finding files matching pattern: /mnt/10b1e8d4-f3a8-46e5-9a1a-c197b4f39011/HTF0002/HTF0002_C384W_205__2023-07-09T03_46_50-Measurement 3/Images/*f*p*-*.tiff
# ...

# %%
files
# Out:
#                                                     plate    well site  \
# 0       HTF0002_C384W_201__1023-07-07T22_09_04-Measure...  r03c03   01
# 1       HTF0002_C384W_201__1023-07-07T22_09_04-Measure...  r03c03   01
# 2       HTF0002_C384W_201__1023-07-07T22_09_04-Measure...  r03c03   01
# 3       HTF0002_C384W_201__1023-07-07T22_09_04-Measure...  r03c03   01
# 4       HTF0002_C384W_201__1023-07-07T22_09_04-Measure...  r03c03   01
# ...                                                   ...     ...  ...
# 352795  HTF0002_C384W_206__2023-07-10T03_24_53-Measure...  r14c22   49
# 352796  HTF0002_C384W_206__2023-07-10T03_24_53-Measure...  r14c22   49
# 352797  HTF0002_C384W_206__2023-07-10T03_24_53-Measure...  r14c22   49
# 352798  HTF0002_C384W_206__2023-07-10T03_24_53-Measure...  r14c22   49
# 352799  HTF0002_C384W_206__2023-07-10T03_24_53-Measure...  r14c22   49
#
#        channel plane                        filename  \
# 0          ch1    01  r03c03f01p01-ch1sk1fk1fl1.tiff
# ...
